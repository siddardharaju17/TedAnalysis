# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
# %matplotlib inline

# %%
tm = pd.read_csv('ted_main.csv')

# %%
type(tm)
tm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550 entries, 0 to 2549
# Data columns (total 17 columns):
# comments              2550 non-null int64
# description           2550 non-null object
# duration              2550 non-null int64
# event                 2550 non-null object
# film_date             2550 non-null int64
# languages             2550 non-null int64
# main_speaker          2550 non-null object
# name                  2550 non-null object
# num_speaker           2550 non-null int64
# published_date        2550 non-null int64
# ratings               2550 non-null object
# related_talks         2550 non-null object
# speaker_occupation    2544 non-null object
# tags                  2550 non-null object
# title                 2550 non-null object
# url                   2550 non-null object
# views                 2550 non-null int64
# dtypes: int64(7), object(10)
# memory usage: 338.8+ KB

# %%
tm.describe()
# Out:
#           comments     duration     film_date    languages  num_speaker  \
# count  2550.000000  2550.000000  2.550000e+03  2550.000000  2550.000000
# mean    191.562353   826.510196  1.321928e+09    27.326275     1.028235
# std     282.315223   374.009138  1.197391e+08     9.563452     0.207705
# min       2.000000   135.000000  7.464960e+07     0.000000     1.000000
# 25%      63.000000   577.000000  1.257466e+09    23.000000     1.000000
# 50%     118.000000   848.000000  1.333238e+09    28.000000     1.000000
# 75%     221.750000  1046.750000  1.412964e+09    33.000000     1.000000
# max    6404.000000  5256.000000  1.503792e+09    72.000000     5.000000
#
#        published_date         views
# count    2.550000e+03  2.550000e+03
# mean     1.343525e+09  1.698297e+06
# std      9.464009e+07  2.498479e+06
# min      1.151367e+09  5.044300e+04
# 25%      1.268463e+09  7.557928e+05
# 50%      1.340935e+09  1.124524e+06
# 75%      1.423432e+09  1.700760e+06
# ...

# %%
tm.head(5)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
# what is the most viewed tedtalk
tm[tm['views'] == tm['views'].max()]
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
#
#                          title  \
# 0  Do schools kill creativity?
#
#                                                  url     views
# ...

# %%
tm['speaker_occupation'].value_counts().head(10)
topspeakers = tm[['name','published_date','speaker_occupation','views']].sort_values('views',ascending=False).head(15)
topspeakers
# Out:
#                                                    name published_date  \
# 0             Ken Robinson: Do schools kill creativity?     26-06-2006
# 1346  Amy Cuddy: Your body language may shape who yo...     01-10-2012
# 677       Simon Sinek: How great leaders inspire action     04-05-2010
# 837             Brené Brown: The power of vulnerability     23-12-2010
# 452   Mary Roach: 10 things you didn't know about or...     19-05-2009
# 1776  Julian Treasure: How to speak so that people w...     27-06-2014
# 201             Jill Bolte Taylor: My stroke of insight     11-03-2008
# 5                    Tony Robbins: Why we do what we do     27-06-2006
# 2114  James Veitch: This is what happens when you re...     08-01-2016
# 1416  Cameron Russell: Looks aren't everything. Beli...     16-01-2013
# 500                  Dan Pink: The puzzle of motivation     23-08-2009
# 1163                Susan Cain: The power of introverts     02-03-2012
# ...

# %%
top = tm['main_speaker'].value_counts().head(6)
top
# Out:
# Hans Rosling            9
# Juan Enriquez           7
# Marco Tempest           6
# Rives                   6
# Nicholas Negroponte     5
# Jacqueline Novogratz    5
# Name: main_speaker, dtype: int64

# %%
fig = plt.figure(figsize=(10,10))
sns.countplot(x='speaker_occupation', data=topspeakers)

# %%
sns.heatmap(tm.corr())

# %%
tm.corr()
# Out:
#                 comments  duration  film_date  languages  num_speaker  \
# comments        1.000000  0.140694  -0.133303   0.318284    -0.035489
# duration        0.140694  1.000000  -0.242941  -0.295681     0.022257
# film_date      -0.133303 -0.242941   1.000000  -0.061957     0.040227
# languages       0.318284 -0.295681  -0.061957   1.000000    -0.063100
# num_speaker    -0.035489  0.022257   0.040227  -0.063100     1.000000
# published_date -0.185936 -0.166324   0.902565  -0.171836     0.049240
# views           0.530939  0.048740   0.006447   0.377623    -0.026389
#
#                 published_date     views
# comments             -0.185936  0.530939
# duration             -0.166324  0.048740
# film_date             0.902565  0.006447
# languages            -0.171836  0.377623
# num_speaker           0.049240 -0.026389
# published_date        1.000000 -0.017920
# views                -0.017920  1.000000

# %%
tm['film_date'] = tm['film_date'].apply(lambda x: datetime.datetime.fromtimestamp( int(x)).strftime('%d-%m-%Y'))
tm['published_date'] = tm['published_date'].apply(lambda x: datetime.datetime.fromtimestamp( int(x)).strftime('%d-%m-%Y'))

# %%
tm.head(5)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  24-02-2006         60   Ken Robinson
# 1  TED2006  24-02-2006         43        Al Gore
# 2  TED2006  23-02-2006         26    David Pogue
# 3  TED2006  25-02-2006         35  Majora Carter
# 4  TED2006  21-02-2006         48   Hans Rosling
#
#                                             name  num_speaker published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1     26-06-2006
# ...

# %%
tm['published_year'] = tm['published_date'].apply(lambda x:x.split("-")[2])

# %%
tm.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  24-02-2006         60   Ken Robinson
# 1  TED2006  24-02-2006         43        Al Gore
# 2  TED2006  23-02-2006         26    David Pogue
# 3  TED2006  25-02-2006         35  Majora Carter
# 4  TED2006  21-02-2006         48   Hans Rosling
#
#                                             name  num_speaker published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1     26-06-2006
# ...

# %%
fig = plt.figure(figsize=(10,5))
sns.countplot('published_year',data=tm)
